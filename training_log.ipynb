# %%
import matplotlib.pyplot as plt

# Epochs and corresponding FNR and validation losses
epochs = list(range(1, 41))  # 1 to 50 epochs
fnr_CNN_20layers = [90.29, 90.76, 90.82, 90.92, 90.99, 91.41, 91.36, 91.26, 91.52, 91.32, 
       91.53, 91.49, 91.56, 91.46, 91.79, 91.49, 91.29, 92.04, 91.88, 92.00, 
       91.40, 92.08, 91.76, 91.87, 91.75, 91.79, 92.02, 91.79, 91.99, 92.24, 
       91.74, 91.50, 91.21, 90.94, 90.73, 89.75, 87.71, 85.01, 82.06, 79.81, 
       77.89, 77.79, 78.81, 76.73, 75.65, 75.23, 73.32, 72.74, 72.23, 71.19]

fnr_FNO_1layer = [79.45, 57.66, 47.91, 42.88, 40.74, 36.57, 33.51, 32.12, 30.07, 30.76, 
       28.68, 27.93, 27.79, 26.34, 24.98, 25.26, 24.60, 23.87, 23.07, 
       23.06, 22.28, 22.26, 21.62, 21.67, 21.65, 21.35, 21.00, 21.34, 
       20.78, 20.89, 20.97, 21.12, 20.62, 20.82, 20.74, 20.74, 20.98, 
       20.89, 20.64, 20.88, 20.74, 20.82, 20.38]

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot FNR on the left y-axis
ax1.set_xlabel('Epochs')
ax1.set_ylabel('FNR (%)', color='tab:red')
ax1.plot(epochs, fnr_CNN_20layers[:40], color='tab:red', label='FNR_CNN_20layers', linestyle='-', marker='o')
ax1.plot(epochs, fnr_FNO_1layer[:40], color='tab:blue', label='FNR_FNO_1layer', linestyle='-', marker='o')
ax1.legend()
# Create a second y-axis for validation loss
# Title and show the plot
fig.tight_layout()
plt.title('FNR vs Epochs')
plt.show()

# %%
validation_loss_CNN = [42.32, 38.87, 38.39, 38.09, 37.92, 37.86, 37.78, 37.72, 37.72, 
                   37.69, 37.63, 37.61, 37.59, 37.58, 37.56, 37.57, 37.56, 37.56, 
                   37.54, 37.57, 37.52, 37.51, 37.53, 37.50, 37.52, 37.49, 37.52, 
                   37.50, 37.48, 37.47, 37.46, 37.42, 37.38, 37.30, 37.17, 36.89, 
                   36.29, 35.14, 34.19, 33.44, 32.96, 32.44, 32.05, 31.79, 31.40, 
                   31.14, 30.93, 30.75, 30.58, 30.44]

validation_loss_FNO = [37.28, 25.61, 21.69, 19.69, 18.65, 17.99, 17.55, 17.24, 
                   17.04, 16.90, 16.64, 16.51, 16.50, 16.36, 16.32, 16.24, 
                   16.13, 16.08, 16.04, 16.05, 16.13, 16.09, 16.07, 16.00, 
                   16.02, 15.96, 15.96, 16.02, 16.05, 15.99, 16.06, 16.11, 
                   16.07, 16.09, 16.00, 16.09, 16.03, 16.10, 16.11, 16.12, 
                   16.16, 16.12, 16.18]

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot FNR on the left y-axis
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Validation loss')
ax1.plot(epochs, validation_loss_CNN[:40], color='tab:red', label='FNR_CNN_20layers', linestyle='-', marker='o')
ax1.plot(epochs, validation_loss_FNO[:40], color='tab:blue', label='FNR_FNO_1layer', linestyle='-', marker='o')
ax1.legend()
# Create a second y-axis for validation loss
# Title and show the plot
fig.tight_layout()
plt.title('Validation vs Epochs')
plt.show()
